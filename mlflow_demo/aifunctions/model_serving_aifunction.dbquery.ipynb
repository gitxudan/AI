-- %%
SELECT ai_query('petstreaming_sales_model',
    request => named_struct("units_sold", CAST(4 AS BIGINT), "price", 32.79, "category", "Accessories"),
    returnType => 'DOUBLE') as prediction;

show tables in ai2605.ai;

select * from ai2605.ai.petstreaming_sales;
