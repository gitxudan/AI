-- %%
%python
import mlflow
exp = mlflow.create_experiment(name='/Users/xudanbetsy@gmail.com/mlflow_exp_demo')
print(exp)

with mlflow.start_run(experiment_id=exp, run_name="first run") as run:
    mlflow.log_param('model', 'LogisticRegression')
    mlflow.log_metric('accuracy', 0.95)
    mlflow.log_metric('precision', 0.98)
    mlflow.log_metric('recall', 0.97)

# - param( , )
# - params ({ ,  , })
# - artifacts
# - model
